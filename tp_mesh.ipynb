# %%
# %load_ext autoreload
# %autoreload
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import random

from mesh import *
from subdivision import *

# %% [markdown]
# # Project : Surface subdivision
